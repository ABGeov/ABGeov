# %% [markdown]
# <a href="https://colab.research.google.com/github/ABGeov/ABGeov/blob/main/Produ%C3%A7%C3%A3o_Hospitalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisando dados de produção hospitalar

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/A150850189_28_143_208.csv', encoding='ISO-8859-1', skiprows=3, sep=';', skipfooter=12, thousands='.', decimal=',') #2ª célula
# Out:
# <ipython-input-260-1f34c61ce7fa>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv('/content/A150850189_28_143_208.csv', encoding='ISO-8859-1', skiprows=3, sep=';', skipfooter=12, thousands='.', decimal=',') #2ª célula

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago    2021/Set  \
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2021/Jan     2021/Fev  \
# 22        -        -        -        -  ... 115991861.17 126730284.94
# 23        -        -        -        -  ...  24727004.66  25600761.42
# 24        -        -        -        -  ...  18889711.53  21544594.04
# 25        -        -        -        -  ...  42638703.48  45715467.93
# 26        -        -        -        -  ...  24484716.93  24156062.77
#
#        2021/Mar     2021/Abr     2021/Mai     2021/Jun     2021/Jul  \
# ...

# %%
dados.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
dados.mean(numeric_only = True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
ultima_coluna = dados.columns[-1]
coluna_mais_recente = dados[ultima_coluna]
print(coluna_mais_recente)
# Out:
# 0     1088059702.25
# 1      475290315.34
# 2     2061943006.93
# 3      352546288.71
# 4     4968811817.17
# 5      337181964.14
# 6     1110344733.46
# 7     4161325769.23
# 8     2450508593.82
# 9     7118540187.61
# 10    2867428082.03
# 11    2796673182.96
# 12    9243658123.01
# 13    2394793268.76
# 14    1313873341.39
# 15   10498497979.38
# 16   21899546392.60
# 17    3710941856.86
# 18   11131868548.73
# 19   44290790025.14
# 20   15672157558.11
# 21    8392938841.37
# 22   13613341350.00
# 23    2516383489.01
# 24    2386584382.72
# 25    5380179246.60
# 26    2778456616.77
# Name: Total, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42502172.22
# 19   180097396.03
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21070201.36
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26645398.35703704

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago')
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
num_bars=len(dados)
colors = plt.cm.viridis(np.linspace(0, 1, num_bars))

axis = dados.plot(x='Unidade da Federação',y='2008/Ago', kind='barh', figsize=(12,10), color=colors)

axis.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))


plt.xticks(rotation=45)
plt.title('Valor por unidade da federação')
plt.show()

# %%
dados["2021/Set"]
# Out:
# 0       1682801.60
# 1                -
# 2       5292323.36
# 3       1496814.75
# 4       4620263.03
# 5        626751.41
# 6        312354.68
# 7      11194657.20
# 8       9371428.06
# 9      16234603.93
# 10      6055806.12
# 11      8962429.99
# 12     35603376.46
# 13      5714532.94
# 14      1509495.66
# 15     24858284.14
# 16     60010941.33
# 17     11916897.69
# 18     43133058.07
# 19    130535317.64
# 20     32660877.10
# 21     18486461.58
# 22     25200345.68
# 23      2445267.12
# 24      7325067.61
# 25     18860370.17
# 26     13173812.37
# Name: 2021/Set, dtype: object

# %%
dados['2021/Set'] = pd.to_numeric(dados['2021/Set'], errors='coerce')
dados.plot(x='Unidade da Federação', y='2021/Set')
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
num_bars=len(dados)
colors = plt.cm.viridis(np.linspace(0, 1, num_bars))
axis = dados.plot(x='Unidade da Federação',y='2021/Set', kind='barh', figsize=(12,10), color=colors)

axis.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.xticks(rotation=45)
plt.title('Valor por unidade da federação')
plt.show()

# %%
dados [['2008/Ago','2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago   2021/Set  \
# ...

# %%
# Selecionar colunas

dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai', '2021/Jun',
#        '2021/Jul', '2021/Ago', '2021/Set', 'Total'],
#       dtype='object', length=293)

# %%
#Selecionando colunas que tem apenas numeros com o dados.mean () ele dá erro. e o .index pega os nomes das colunas e cria uma lista de python não serie  através do tolist
# Com este código conseguimos trazer a lista mas não criar uma lista de Python, para isso precisamos de outro código
dados.select_dtypes(include='number').mean().index.tolist()
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
# ...

# %%
#Neste código retiramos o .mean() para não ter o erro do numerico para str
colunas_usaveis = dados.select_dtypes(include='number').columns.tolist()

#.insert(0 Primeira posição da lista a coluna que quero é 'Unidade de Federação) e o [:5] quero apenas os 5 primeiros elementos da lista, neste caso não posso usar o .head() pois não é uma serie
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
#Criar uma serie

dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2021/Jan  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ... 10045624.39
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  4175526.06
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 27406458.57
# 3   808448.39   771687.83   876091.18   896952.53  ...  3557821.99
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 39042349.46
#
#      2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun    2021/Jul  \
# ...

# %%
#.set_index consigo escolher qual coluna será o indice, ao invés de 0,1,2...

dados_usaveis = dados_usaveis.set_index('Unidade da Federação')
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis['2007/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia     4209.37
# 12 Acre        10470.07
# 13 Amazonas    35752.72
# 14 Roraima      4785.91
# 15 Pará       181159.29
# Name: 2007/Ago, dtype: float64

# %%
#Localizar index, retorna uma Serie .loc por index e [] busca coluna

dados_usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# 2021/Set            NaN
# Total      475290315.34
# Name: 12 Acre, Length: 171, dtype: float64

# %%
# iloc buscar por numero da linha

dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# 2021/Set            NaN
# Total      475290315.34
# Name: 12 Acre, Length: 171, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# grafico melhor como serie temporal, ou seja o eixo x seja registrado pelo tempo não faz sentido por estado não posso colocar x= coluna pois quero todas as colunas da serie e o y seja o estado, precisamos usar o plot, mas na vivencia para trocar completamente podemos usar algo diferente transpor uma matriz .T, mudar minha serie, oque é coluna vira linha e oque era linha vira coluna
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))

#o total esta discriminado na serie, fazendo parte do grafico oque duplica os nosso resultados. T.tail()precisamos dropar o total
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2021/Jun               14435903.47   3458187.11   22175398.40   3475205.55
# 2021/Jul               11834435.10   2302711.01   21614943.55   3320807.96
# 2021/Ago                7371334.84   1196754.85   13806958.66   2907871.07
# 2021/Set                1682801.60          NaN    5292323.36   1496814.75
# Total                1088059702.25 475290315.34 2061943006.93 352546288.71
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2021/Jun               43876590.47   5469150.38    6349488.16   51958573.27
# 2021/Jul               33718084.12   4136950.62    4610170.61   37775425.78
# 2021/Ago               20837865.89   1875241.91    2304080.49   25779674.83
# 2021/Set                4620263.03    626751.41     312354.68   11194657.20
# Total                4968811817.17 337181964.14 1110344733.46 4161325769.23
#
# ...

# %%
dados_usaveis = dados_usaveis.drop('Total', axis=1)

# %%
dados_usaveis.T.plot(figsize=(12,6))

##colocando titulo geral e por eixo, e alocando a legenda.
plt.title('Valor por Unidade da Federação versus mês')
plt.ylabel('Valor')
plt.xlabel('Mês')
plt.legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=5, borderaxespad=0.)

plt.show()

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
dados_usaveis.sample(7).T.plot(figsize=(10,6))

plt.title('Valor por Unidade da Federação')
plt.ylabel('Valor')
plt.xlabel('Mês')
plt.legend(bbox_to_anchor=(0, -0.1), loc='upper left', ncol=4, borderaxespad=0.)

plt.show()

# %%
import numpy as np
##numero aleatorio seed semente
np.random.seed(524387)
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206493861.30 70301089.50 79119005.51 79046322.41
# ...

# %%
dados_usaveis['Total']=dados_usaveis.sum(axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
## ordenar nosso DataFrame a linha primeira seja o maior valor

ordenados_por_total = dados_usaveis.sort_values(by='Total', ascending=False)
ordenados_por_total = ordenados_por_total.drop('Total', axis=1)

#ordenados_por_total.drop('Total', axis =1, inplace=True)
ordenados_por_total
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo           1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais         971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná               554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul   1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro       469469.34  921646.57  2994664.57  7250528.08
# 29 Bahia                135146.36  448349.75  1382038.11  3348779.62
# 26 Pernambuco           400640.85 1088340.42  2973553.48  6699828.82
# 42 Santa Catarina       693955.05 1092964.12  3562300.82  7578502.38
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 52 Goiás                179395.82  418053.58  1198730.25  2712117.54
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# ...

# %%
#Criar lista com regiões e inserir coluna 'região'
#regioes = ['Norte','Norte','Norte','Norte','Norte','Norte','Norte','Nordeste','Nordeste','Nordeste','Nordeste','Nordeste','Nordeste','Nordeste','Nordeste','Nordeste','Sudeste','Sudeste','Sudeste','Sudeste','Sul','Sul','Sul','Centro-Oeste','Centro-Oeste','Centro-Oeste','Centro-Oeste']
#dados_usaveis['Região'] = regioes

# %%
#dados_numericos = ordenados_por_total.select_dtypes(include='number')
#dados_numericos.head(5).T.plot(figsize=(10, 6))
#plt.show()

# %%
#dados_numericos.head(5)

# %%
colunas_interessadas = ordenados_por_total.columns[7:]

# %%
ordenados_por_total = ordenados_por_total[colunas_interessadas]
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
axis = ordenados_por_total.head(5).T.plot(figsize=(10,6))
axis.set_ylabel("Gasto aprovado em milhões de reais")
axis.set_xlabel("Mês")
# Out:
# Text(0.5, 0, 'Mês')

# %%
ordenados_por_total = ordenados_por_total / 1_000_000

# %%
axis = ordenados_por_total.head(5).T.plot(figsize=(10,6))
axis.set_ylabel("Gasto aprovado em milhões de reais")
axis.set_xlabel("Mês")
# Out:
# Text(0.5, 0, 'Mês')

# %%
meses_filtrados = ordenados_por_total.columns[46:]
axis = ordenados_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
axis.set_ylabel("Gasto aprovado em milhões de reais")
axis.set_xlabel("Mês")
# Out:
# Text(0.5, 0, 'Mês')

# %%
#criar uma função de plotagem
def plota_gastos_por_mes(dados, figsize=(10,6)):
   axis = dados.T.plot(figsize=figsize)
   axis.set_ylabel("Gasto aprovado em milhões de reais")
   axis.set_xlabel("Mês")

# %%
plota_gastos_por_mes(ordenados_por_total[meses_filtrados].head(3))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[44:70]].head(3))
plt.ylim(0,320)
# Out:
# (0.0, 320.0)

# %%
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-12:]].head(3))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-61:]].head(3))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total.head(5))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total.head(5), figsize=(6,6))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %%
plota_gastos_por_mes(ordenados_por_total.head(5), figsize=(15,6))
plt.ylim(0,640)
plt.grid(True, linestyle=':', alpha=0.7, color = 'gray', linewidth=0.5)

# %%
mes_mais_recente = ordenados_por_total.columns[-2]
mes_mais_recente
# Out:
# '2021/Ago'

# %%
gastos_do_mais_recente = ordenados_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           301.99
# 31 Minas Gerais        139.16
# 41 Paraná               91.19
# 43 Rio Grande do Sul    74.95
# 33 Rio de Janeiro       94.14
# Name: 2021/Ago, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc['41 Paraná']
# Out:
# Unidade da Federação
# 35 São Paulo             3.31
# 31 Minas Gerais          1.53
# 41 Paraná                1.00
# 43 Rio Grande do Sul     0.82
# 33 Rio de Janeiro        1.03
# 29 Bahia                 0.68
# 26 Pernambuco            0.79
# 42 Santa Catarina        0.54
# 23 Ceará                 0.39
# 52 Goiás                 0.49
# 15 Pará                  0.23
# 21 Maranhão              0.28
# 32 Espírito Santo        0.30
# 24 Rio Grande do Norte   0.18
# 25 Paraíba               0.18
# 53 Distrito Federal      0.24
# 50 Mato Grosso do Sul    0.12
# 22 Piauí                 0.17
# 27 Alagoas               0.12
# 51 Mato Grosso           0.22
# 13 Amazonas              0.15
# 28 Sergipe               0.05
# 17 Tocantins             0.03
# 11 Rondônia              0.08
# 12 Acre                  0.01
# 14 Roraima               0.03
# 16 Amapá                 0.02
# Name: 2021/Ago, dtype: float64

# %%
tabela_de_comparação = gastos_do_mais_recente / gastos_do_mais_recente.loc['41 Paraná']
tabela_de_comparação.head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           3.31
# 31 Minas Gerais        1.53
# 41 Paraná              1.00
# 43 Rio Grande do Sul   0.82
# 33 Rio de Janeiro      1.03
# Name: 2021/Ago, dtype: float64

# %%
tabela_de_comparação.plot(kind='bar', color='red')
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
num_barss=len(dados)
colors = plt.cm.viridis(np.linspace(0, 1, num_barss))

tabela_de_comparação = tabela_de_comparação.sort_values(ascending=False)
tabela_de_comparação.plot(kind='bar', color=colors, figsize=(15,6))
plt.title('Gastos do mês')
plt.ylabel('Gastos em relação ao outro')
plt.grid(True, linestyle = '--')
